# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# **Goal:** Understand the dataset — shape, types, distributions, missing values.
#
# **Author:** [Your Name]
# **Date:** [Date]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Make plots look nice
plt.style.use('ggplot')
# %matplotlib inline

print('Libraries loaded ✅')

# %% [markdown]
# ## 1. Load Data

# %%
# Example: Load your dataset here
# df = pd.read_csv('../data/raw/your_file.csv')
# print(df.shape)
# df.head()

# %% [markdown]
# ## 2. Basic Info

# %%
# df.info()
# df.describe()

# %% [markdown]
# ## 3. Missing Values

# %%
# df.isnull().sum()

# %% [markdown]
# ## 4. Visualizations
#
# Add your plots here.

# %%
# Example plot
# df['column_name'].hist(bins=30)
# plt.title('Distribution of X')
# plt.show()

# %% [markdown]
# ## 5. Key Findings
#
# - Finding 1
# - Finding 2
# - Finding 3
